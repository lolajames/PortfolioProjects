# %% [markdown]
# <a href="https://colab.research.google.com/github/lolajames/PortfolioProjects/blob/main/Data_Science_ML_Week1_Labs_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Variables: Are containers for storing data values.
#Rules a variable must follow: It must start with a letter or underscore(_). It can only contain letters,numbers and underscores. Cannot start with a number.

# %%
#Variable assignment.
Firstname="Natalie"
print(Firstname)
# Out:
# Natalie

# %%
#Checking for Data type
x=2
y=3.14
z=2+3j
x
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#The sequence:Sequence is a pattern or the arrangement or set of data put together.
#Types of Sequence:List,Tuple,Range

mylist_=[1,2,3,4,5]
mytuple=(1,2,3,4,5)
myrange=range(1,5)
print(type(mylist_))
print(type(mytuple))
print(type(myrange))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'range'>

# %%
#Mapping(Key then value)
PyroCyber={"name":"Eric","Age":25,"Sport":"Tennis","Food":"Fufu"}
PyroCyber["name"]
print(PyroCyber)
# Out:
# {'name': 'Eric', 'Age': 25, 'Sport': 'Tennis', 'Food': 'Fufu'}
