# %% [markdown]
# <a href="https://colab.research.google.com/github/lolajames/PortfolioProjects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Letters=["a","b","c","d","e"]
Letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#append
Letters.append("f")
print(Letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
Letters.extend(["g","h"])
print(Letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
Letters.insert(5,"X")
print(Letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'X', 'f', 'g', 'h']

# %%
Letters.remove("X")
print(Letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#Index
Index=Letters.index("e")
print(Index)
# Out:
# 4

# %%
#Count
Count=Letters.count('h')
print(Count)
# Out:
# 1

# %%
#Sort
Letters.sort()
Letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#Reverse
Letters.reverse()
Letters
# Out:
# ['h', 'g', 'f', 'e', 'd', 'c', 'b', 'a']

# %%
#Tuple
Lola=("a","b","c","d","e")
Lola
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
#Count
Count = Lola.count("a")
print(Count)
# Out:
# 1

# %%
#Index
Index=Lola.index("d")
print(Index)
# Out:
# 3

# %%
print(Lola[3])
# Out:
# d

# %%
#Dictionary: Are unordered collection key-values pairs
my_Dictionary=dict(name="Lola",age=24,City="lagos")
my_Dictionary
# Out:
# {'name': 'Lola', 'age': 24, 'City': 'lagos'}

# %%
my_Dictionary= dict( [('name', ['lola','james','love']),('age', [24,27,28]),('city', ['Lagos','Lekki','Ikotun'])] )
my_Dictionary
# Out:
# {'name': ['lola', 'james', 'love'],
#  'age': [24, 27, 28],
#  'city': ['Lagos', 'Lekki', 'Ikotun']}

# %%
my_Dictionary={"names":("Lola","james","love"),"age":24,"City":"lagos"}
my_Dictionary
# Out:
# {'names': ('Lola', 'james', 'love'), 'age': 24, 'City': 'lagos'}

# %%
age=my_Dictionary.get("age")
age
# Out:
# 24

# %%
Items=my_Dictionary.items()
Items
# Out:
# dict_items([('names', ('Lola', 'james', 'love')), ('age', 24), ('City', 'lagos')])

# %%
keys=my_Dictionary.keys()
keys
# Out:
# dict_keys(['names', 'age', 'City'])

# %%
values=my_Dictionary.values()
values
# Out:
# dict_values([('Lola', 'james', 'love'), 24, 'lagos'])

# %%
my_Dictionary.update({"gender":["Female","Female","Female"]})
my_Dictionary
# Out:
# {'names': ('Lola', 'james', 'love'),
#  'age': 24,
#  'City': 'lagos',
#  'gender': ['Female', 'Female', 'Female']}
